# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd

# %%
df = pd.read_csv("USA_Predictors_of_How_Counties_Vote.csv")

# %%
print(df)
# Out:
#                        name  % Home Ownership  % Married Couples  % Poverty  \
# 0        Autauga County, AL         73.290648          67.087476  15.185172
# 1        Baldwin County, AL         75.245274          64.435569  10.354073
# 2        Barbour County, AL         60.898876          50.954394  30.668689
# 3           Bibb County, AL         74.415905          59.077670  18.127181
# 4         Blount County, AL         78.778721          68.772974  13.551516
# ...                     ...               ...                ...        ...
# 3137  Sweetwater County, WY         76.222380          66.469602  11.455375
# 3138       Teton County, WY         60.405810          58.200987   6.149733
# 3139       Uinta County, WY         77.056733          73.956066  11.343107
# 3140    Washakie County, WY         76.493314          67.941064  10.505539
# 3141      Weston County, WY         83.016257          69.071397  14.473096
#
# ...

# %%
a=[df["% Asian"]]
b=[df["% Bachelor's Degree or Higher"]]
h=[df["% Home Ownership"]]
hs=[df["% Hispanic"]]
p=[df["% Poverty"]]
w=[df["% Non-Hispanic White"]]
y=[df["Margin D"]]

# %%
plt.scatter(b,y,s=1)

# %%
plt.scatter(h,y,s=1)

# %%
plt.scatter(b,h,c=y,cmap="RdBu",s=10)

# %%
plt.scatter(a,w,c=y,cmap="RdBu",s=10)
